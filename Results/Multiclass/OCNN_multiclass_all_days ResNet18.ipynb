# %%
import torchvision
import torch
import numpy as np
import os
import PIL.Image
import time
import copy
import seaborn as sn
import pandas as pd
import sklearn.metrics
from matplotlib import pyplot as plt
from math import ceil

# %%
class OstVisDataset(torch.utils.data.Dataset):
    def __init__(self, roots, transforms, subset, label_map, exclude_subfolders = None, split = (.6,.2,.2)):
        # list of root folders
        self.roots = roots

        # list of subfolders to exclude from sampling (e.g. if you only want control_well 1 and adipogenic differentiation)
        self.exclude_subfolders = exclude_subfolders

        # torchvision composed transforms
        self.transforms = transforms

        # dict mapping subfolder names to labels
        self.label_map = label_map

        # getting files
        self.enumerated_files = self.depthwise_enumerate(subset,split)

    def depthwise_enumerate(self, subset, split): 
        all_files = []
        # for each root folder
        for i in self.roots:
            # get subfolders
            folders = [f for f in os.listdir(i) if '.' not in f]
            
            if self.exclude_subfolders:
                folders = [f for f in folders if f.lower() not in self.exclude_subfolders]

            for j in folders:
                # get files from folders
                files = [i + j + '/' + f for f in os.listdir(i + j) if '.tif' in f]

                # copy files list
                files_copy = files.copy()

                # calculate sample size then select the proper subset
                train_size = ceil(len(files) * split[0])
                
                if subset == 'train':
                    upper_bound = train_size
                    files = files_copy[:upper_bound]
                elif subset == 'valid': 
                    lower_bound = train_size
                    upper_bound = train_size + ceil(len(files) * split[1])
                    files = files_copy[lower_bound:upper_bound]
                else:
                    lower_bound = train_size + ceil(len(files) * split[1])
                    files = files_copy[lower_bound:]
                
                # extend all files list by the file list for subfolder j
                all_files.extend(files)
        
        # return flat list of files
        return all_files
    
    def __len__(self):
        return len(self.enumerated_files)
    
    def __getitem__(self, idx):
        # check type
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        # get image at position idx in enumerated list
        image_path = self.enumerated_files[idx]
        image = PIL.Image.open(image_path).convert('RGB')
        
        # apply tranforms
        image = self.transforms(image)
        
        # separate subfolder name from path
        image_path_parts = image_path.split('/')

        # determine label
        label = self.label_map[image_path_parts[1].lower()]
        
        # return ((path, image), output) pair We will use path to track accuracy for each class: 7 day, 10 day, etc
        return ((image_path_parts[0], image), label)

# %%
def load_model(device):
    model_ft = torchvision.models.resnet18(weights=torchvision.models.ResNet18_Weights.DEFAULT)
    num_ftrs = model_ft.fc.in_features
    # Here the size of each output sample is set to 2.
    # Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
    model_ft.fc = torch.nn.Linear(num_ftrs, 3)

    model_ft = model_ft.to(device)

    criterion = torch.nn.CrossEntropyLoss()

    # Observe that all parameters are being optimized
    optimizer_ft = torch.optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

    # Decay LR by a factor of 0.1 every 7 epochs
    exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
    return model_ft, criterion, exp_lr_scheduler, optimizer_ft

def train_model(model, criterion, optimizer, scheduler, device, dataloaders, dataset_sizes, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    train_epoch_accuracies = []
    val_epoch_accuracies = []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)


        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0


            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs[1].to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    #print("outputs", outputs)
                    _, preds = torch.max(outputs, 1)
                    #print("preds", preds)
                    loss = criterion(outputs, labels)
                    #print(preds)
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            if phase == 'train':
                train_epoch_accuracies.append(float(epoch_acc))
            if phase == 'valid':
                val_epoch_accuracies.append(float(epoch_acc))
                
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best valid acc: {best_acc:4f}')
    plt.plot([i + 1 for i in range(num_epochs)], train_epoch_accuracies, label='Train')
    plt.plot([i + 1 for i in range(num_epochs)], val_epoch_accuracies, label = 'Validation')
    plt.legend()
    plt.xlabel('Epoch', fontname='Arial', fontsize=12)
    plt.ylabel('Accuracy', fontname='Arial', fontsize=12)
    plt.show()

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
# initial construction of torch Dataset object
split_names = ['train', 'valid', 'test']
roots = ['2.28/', '1day.4.13/', '3.3/', '2day.4.14/', '3day.4.15/', '3.6/', '5day.4.17/','ZOE_ALL/']
label_map = {
    'control_well 1': 0,
    'adipogenic differentiation' : 1,
    'osteogenic differentiation' : 2,
    'control' : 0,
    'adi-well-1' : 1,
    'adi-well-2' : 1,
    'ctrl-well-1' : 0,
    'ctrl-well-2' : 0,
    'ost-well-1' : 2,
    'ost-well-2' : 2,
    'osteogenic' : 2,
    'adi' : 1,
    'crl' : 0,
    'ost' : 2
}

data_transforms = {
    'train': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.RandomResizedCrop(224),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}


datasets = {split: OstVisDataset(roots= roots,
                      transforms= data_transforms[split],
                      subset= split,
                      label_map = label_map,
                      exclude_subfolders=['split', 'ost+adi-well-1', 'ost+adi-well-2', 'adipogenic + osteogenic', 'osteogenic + adipogenic'],
                      split=(.6,.2,.2)) 
                      for split in split_names
            }

for i in datasets['train'].enumerated_files:
    if i in datasets['valid'].enumerated_files or i in datasets['test'].enumerated_files:
        print('Duplicate Found: ', i)

for i in datasets['valid'].enumerated_files:
    if i in datasets['train'].enumerated_files or i in datasets['test'].enumerated_files:
        print('Duplicate Found: ', i)

# constructing dataloaders
dataloaders = {split : torch.utils.data.DataLoader(datasets[split], shuffle=True, batch_size=128, num_workers=0) for split in split_names}

# getting lens
dataset_sizes = {split : len(datasets[split]) for split in split_names}
print(dataset_sizes)

# constructing device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# load model
model_ft, criterion, exp_lr_scheduler, optimizer_ft = load_model(device)

print('Train files:', datasets['train'].enumerated_files)
print('Validation files:', datasets['valid'].enumerated_files)
print('Testing files:', datasets['test'].enumerated_files)
# Out:
# {'train': 1407, 'valid': 473, 'test': 456}
# Train files: ['2.28/adipogenic differentiation/0228-pl2-adi-w1-df-1.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-10.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-11.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-12.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-13.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-14.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-15.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-16.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-17.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-18.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-19.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-2.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-20.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-21.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-22.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-23.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-24.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-25.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-26.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-27.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-28.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-29.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-3.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-30.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-31.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-32.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-33.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-34.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-38.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-39.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-4.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-40.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-41.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-42.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-43.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-44.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-45.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-46.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-47.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-48.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-49.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-5.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-50.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-6.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-7.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-8.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-9.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-1.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-10.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-11.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-12.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-13.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-14.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-15.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-16.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-17.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-18.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-19.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-2.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-1.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-10.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-11.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-12.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-13.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-14.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-15.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-16.tif', '2.28/c ...
# Validation files: ['2.28/adipogenic differentiation/0228-pl2-adi-w2-df-20.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-21.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-22.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-23.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-24.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-25.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-26.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-27.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-28.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-29.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-3.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-30.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-31.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-32.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-33.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-34.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-35.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-36.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-37.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-38.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-19.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-2.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-20.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-21.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-22.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-23.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-24.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-25.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-26.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-27.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-28.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-29.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-3.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-30.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-31.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-32.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-33.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-34.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-35.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-36.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-19.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-2.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-20.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-21.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-22.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-23.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-24.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-25.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-26.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-27.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-28.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-29.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-3.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-30.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-31.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-32.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-33.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-34.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-35.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-36.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13459.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13460.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13461.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13462.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13463.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13464.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13465.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13466.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13467.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13468.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13469.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13470.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13471.tif', '1day.4 ...
# Testing files: ['2.28/adipogenic differentiation/0228-pl2-adi-w2-df-39.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-4.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-40.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-41.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-42.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-43.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-44.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-45.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-46.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-47.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-48.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-49.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-5.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-50.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-6.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-7.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-8.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-9.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-37.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-38.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-39.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-4.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-40.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-41.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-42.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-43.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-44.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-45.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-46.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-47.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-48.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-49.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-5.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-50.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-6.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-7.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-8.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-9.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-37.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-38.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-4.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-40.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-41.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-42.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-43.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-44.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-46.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-47.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-48.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-49.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-5.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-50.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-6.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-7.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-8.tif', '2.28/osteogenic differentiation/0228-pl2-ost-w2-df-9.tif', '2.28/osteogenic differentiation/IMG_BRIGHTFIELD_11682.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13480.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13481.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13482.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13483.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13484.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13485.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13486.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13487.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13488.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13489.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13490.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13491.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13492.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13493.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13494.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13495.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13496.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_134 ...

# %%
# train model
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,device, dataloaders, dataset_sizes,
                       num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 1.0410 Acc: 0.4684
# valid Loss: 1.1391 Acc: 0.3615
#
# Epoch 1/29
# ----------
# train Loss: 0.7301 Acc: 0.7228
# valid Loss: 0.8413 Acc: 0.5539
#
# Epoch 2/29
# ----------
# train Loss: 0.5204 Acc: 0.8436
# valid Loss: 0.6261 Acc: 0.7526
#
# Epoch 3/29
# ----------
# train Loss: 0.4161 Acc: 0.8650
# valid Loss: 0.5771 Acc: 0.7548
#
# Epoch 4/29
# ----------
# train Loss: 0.3442 Acc: 0.8799
# valid Loss: 0.4030 Acc: 0.8224
#
# Epoch 5/29
# ----------
# train Loss: 0.2937 Acc: 0.8984
# valid Loss: 0.6104 Acc: 0.7125
#
# Epoch 6/29
# ----------
# train Loss: 0.2485 Acc: 0.9154
# valid Loss: 1.0730 Acc: 0.7294
#
# Epoch 7/29
# ----------
# train Loss: 0.2344 Acc: 0.9183
# valid Loss: 0.2898 Acc: 0.8795
#
# Epoch 8/29
# ----------
# train Loss: 0.2312 Acc: 0.9282
# valid Loss: 0.2862 Acc: 0.8985
#
# Epoch 9/29
# ----------
# train Loss: 0.2227 Acc: 0.9325
# valid Loss: 0.2596 Acc: 0.8943
#
# Epoch 10/29
# ----------
# train Loss: 0.2126 Acc: 0.9318
# valid Loss: 0.2446 Acc: 0.9070
#
# Epoch 11/29
# ----------
# train Loss: 0.2097 Acc: 0.9296
# valid Loss: 0.2471 Acc: 0.9006
#
# Epoch 12/29
# ----------
# train Loss: 0.2130 Acc: 0.9282
# valid Loss: 0.2407 Acc: 0.9027
#
# Epoch 13/29
# ----------
# train Loss: 0.2269 Acc: 0.9147
# valid Loss: 0.2465 Acc: 0.9049
#
# Epoch 14/29
# ----------
# train Loss: 0.2042 Acc: 0.9325
# valid Loss: 0.2424 Acc: 0.9006
#
# Epoch 15/29
# ----------
# train Loss: 0.2185 Acc: 0.9282
# valid Loss: 0.2404 Acc: 0.9027
#
# Epoch 16/29
# ----------
# train Loss: 0.2182 Acc: 0.9247
# valid Loss: 0.2398 Acc: 0.9006
#
# Epoch 17/29
# ----------
# train Loss: 0.2075 Acc: 0.9332
# valid Loss: 0.2434 Acc: 0.8985
#
# Epoch 18/29
# ----------
# train Loss: 0.2055 Acc: 0.9268
# valid Loss: 0.2469 Acc: 0.8964
#
# Epoch 19/29
# ----------
# train Loss: 0.2074 Acc: 0.9339
# valid Loss: 0.2452 Acc: 0.9049
#
# Epoch 20/29
# ----------
# train Loss: 0.2026 Acc: 0.9339
# valid Loss: 0.2408 Acc: 0.9091
#
# Epoch 21/29
# ----------
# train Loss: 0.2116 Acc: 0.9282
# valid Loss: 0.2396 Acc: 0.9049
#
# Epoch 22/29
# ----------
# train Loss: 0.2227 Acc: 0.9240
# valid Loss: 0.2416 Acc: 0.9112
#
# Epoch 23/29
# ----------
# train Loss: 0.2136 Acc: 0.9311
# valid Loss: 0.2382 Acc: 0.9133
#
# Epoch 24/29
# ----------
# train Loss: 0.2105 Acc: 0.9197
# valid Loss: 0.2424 Acc: 0.9006
#
# Epoch 25/29
# ----------
# train Loss: 0.2090 Acc: 0.9289
# valid Loss: 0.2410 Acc: 0.9027
#
# Epoch 26/29
# ----------
# train Loss: 0.2009 Acc: 0.9289
# valid Loss: 0.2403 Acc: 0.9049
#
# Epoch 27/29
# ----------
# train Loss: 0.2048 Acc: 0.9275
# valid Loss: 0.2387 Acc: 0.9091
#
# Epoch 28/29
# ----------
# train Loss: 0.2077 Acc: 0.9318
# valid Loss: 0.2378 Acc: 0.9133
#
# Epoch 29/29
# ----------
# train Loss: 0.1941 Acc: 0.9431
# valid Loss: 0.2425 Acc: 0.9112
#
# Training complete in 130m 60s
# Best valid acc: 0.913319

# %%
# only run this after training
torch.save(model_ft.wstate_dict(), 'OCNN_Multiclass_all_days_State_Dict_RESNET18')

# %%
# load model from dict
model_ft.load_state_dict(torch.load('OCNN_Multiclass_all_days_State_Dict_RESNET18'))

model_ft.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=3, bias=True)
# )

# %%
true = []
pred = []
pred_probs = []

# making predictions
for i in dataloaders['test']:
    true.extend(list(zip([j for j in i[0][0]], [int(j) for j in i[1]])))
    evals = model_ft(i[0][1])
    pred.extend([int(torch.argmax(j)) for j in evals])
    pred_probs.extend([torch.softmax(j, 0).detach().numpy() for j in evals])

# separating class label from filename 
true_numeric = [i[1] for i in true]

# overall metrics
print('Overall Accuracy: ', sklearn.metrics.accuracy_score(true_numeric, pred))
print('Overall One vs Rest AUC: ', sklearn.metrics.roc_auc_score(true_numeric, pred_probs, multi_class='ovr', average='weighted'))
# Out:
# Overall Accuracy:  0.9407894736842105
# Overall One vs Rest AUC:  0.992480164908182

# %%
# labels for visual
class_names = ['No Differentiation', 'Adipogenic', 'Osteogenic']

# numeric confusion matrix
confusion_matrix = sklearn.metrics.confusion_matrix(true_numeric, pred)

# convert to df and make fancy confusion matrix
confusion_matrix_df = pd.DataFrame(confusion_matrix, index = class_names, columns = class_names)

sn.set(font_scale = .8)
sn.heatmap(confusion_matrix_df, annot=True, fmt='g', cbar=False, cmap='Blues', annot_kws={'fontsize' : 12})
# Out:
# <Axes: >

# %%
# Control vs Rest roc curve
control_vs_rest_true = [1 if i == 0 else 0 for i in true_numeric]
sklearn.metrics.RocCurveDisplay.from_predictions(control_vs_rest_true, np.array(pred_probs)[:,0])
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance (AUC = 0.5)')
plt.title('Control vs Rest ROC Curve', fontname='Arial', fontsize=12)
plt.xlabel('False Positive Rate', fontname='Arial', fontsize=12)
plt.ylabel('True Positive Rate', fontname='Arial', fontsize=12)
plt.legend()

# %%
# Control vs Rest roc curve
adi_vs_rest_true = [1 if i == 1 else 0 for i in true_numeric]
sklearn.metrics.RocCurveDisplay.from_predictions(adi_vs_rest_true, np.array(pred_probs)[:,1])
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance (AUC = 0.5)')
plt.title('Adipogenic vs Rest ROC Curve', fontname='Arial', fontsize=12)
plt.xlabel('False Positive Rate', fontname='Arial', fontsize=12)
plt.ylabel('True Positive Rate', fontname='Arial', fontsize=12)
plt.legend()

# %%
# Ost vs Rest roc curve
osteo_vs_rest_true = [1 if i == 2 else 0 for i in true_numeric]
sklearn.metrics.RocCurveDisplay.from_predictions(osteo_vs_rest_true, np.array(pred_probs)[:,2])
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance (AUC = 0.5)')
plt.title('Osteogenic vs Rest ROC Curve', fontname='Arial', fontsize=12)
plt.xlabel('False Positive Rate', fontname='Arial', fontsize=12)
plt.ylabel('True Positive Rate', fontname='Arial', fontsize=12)
plt.legend()

# %%
# computing metrics by class

all = []

for i in zip(true, pred, pred_probs):
    # basically flattening the true and pred class. i[0][0] is filename, i[0][1] is true class, i[1] is prediction
    all.append((i[0][0], i[0][1], i[1], i[2]))

# convert to dataframe for easy slicing
all_preds_and_labels = pd.DataFrame(all, columns=['File Group', 'True Class', 'Prediction', 'Predicted Probs'])
metrics_dict = dict()

#print(all_preds_and_labels)

# compute metrics for each filename
for i in set(all_preds_and_labels['File Group']):
    slice = all_preds_and_labels[all_preds_and_labels['File Group'] == i]
    metrics_dict['{} Accuracy'.format(i)] = sklearn.metrics.accuracy_score(np.array(slice['True Class']), np.array(slice['Prediction']))
    metrics_dict['{} Overall One vs Rest AUC'.format(i)] = sklearn.metrics.roc_auc_score(slice['True Class'], [j for j in slice['Predicted Probs']], multi_class='ovr', labels=[0, 1, 2])

for i in metrics_dict.items():
    print(i)
# Out:
# ('2.28 Accuracy', 0.9649122807017544)
# ('2.28 Overall One vs Rest AUC', 1.0)
# ('2day.4.14 Accuracy', 0.9661016949152542)
# ('2day.4.14 Overall One vs Rest AUC', 0.998268106162843)
# ('1day.4.13 Accuracy', 0.9649122807017544)
# ('1day.4.13 Overall One vs Rest AUC', 0.9995383194829178)
# ('3.6 Accuracy', 0.9107142857142857)
# ('3.6 Overall One vs Rest AUC', 0.977587971396021)
# ('3day.4.15 Accuracy', 0.8305084745762712)
# ('3day.4.15 Overall One vs Rest AUC', 0.9871007647323436)
# ('5day.4.17 Accuracy', 0.95)
# ('5day.4.17 Overall One vs Rest AUC', 0.9987499999999999)
# ('3.3 Accuracy', 1.0)
# ('3.3 Overall One vs Rest AUC', 1.0)
# ('ZOE_ALL Accuracy', 0.9491525423728814)
# ('ZOE_ALL Overall One vs Rest AUC', 0.9771479982006297)

# %%
true_train = []

for i in dataloaders['train']:
    true_train.extend(list(zip([j for j in i[0][0]], [int(j) for j in i[1]], [j for j in range(len(i[1]))])))
print(true_train)
all_train_labels = pd.DataFrame(true_train, columns=['File Group', 'True Class', 'ID'])
# Out:
# [('2.28', 3, 0), ('ZOE_ALL', 0, 1), ('1day.4.13', 1, 2), ('3day.4.15', 0, 3), ('2day.4.14', 1, 4), ('ZOE_ALL', 2, 5), ('3.3', 2, 6), ('2.28', 1, 7), ('5day.4.17', 1, 8), ('2.28', 1, 9), ('3.6', 0, 10), ('ZOE_ALL', 0, 11), ('ZOE_ALL', 3, 12), ('3.6', 0, 13), ('3.6', 2, 14), ('3.3', 3, 15), ('5day.4.17', 0, 16), ('ZOE_ALL', 1, 17), ('ZOE_ALL', 3, 18), ('ZOE_ALL', 1, 19), ('3day.4.15', 2, 20), ('1day.4.13', 0, 21), ('5day.4.17', 2, 22), ('3.6', 1, 23), ('3.3', 3, 24), ('ZOE_ALL', 0, 25), ('ZOE_ALL', 3, 26), ('2.28', 1, 27), ('3.6', 3, 28), ('ZOE_ALL', 1, 29), ('ZOE_ALL', 0, 30), ('3day.4.15', 2, 31), ('2.28', 0, 32), ('ZOE_ALL', 3, 33), ('5day.4.17', 0, 34), ('ZOE_ALL', 3, 35), ('5day.4.17', 2, 36), ('3.6', 1, 37), ('3.6', 0, 38), ('3.6', 2, 39), ('3.3', 2, 40), ('2.28', 0, 41), ('3day.4.15', 0, 42), ('3.6', 2, 43), ('1day.4.13', 1, 44), ('3day.4.15', 0, 45), ('3.3', 3, 46), ('1day.4.13', 1, 47), ('3.3', 0, 48), ('ZOE_ALL', 3, 49), ('3.6', 1, 50), ('3.3', 1, 51), ('5day.4.17', 0, 52), ('3day.4.15', 1, 53), ('1day.4.13', 1, 54), ('1day.4.13', 0, 55), ('ZOE_ALL', 3, 56), ('ZOE_ALL', 2, 57), ('2.28', 2, 58), ('3.6', 1, 59), ('3day.4.15', 0, 60), ('3.3', 2, 61), ('2day.4.14', 0, 62), ('ZOE_ALL', 1, 63), ('2day.4.14', 0, 64), ('1day.4.13', 1, 65), ('2.28', 1, 66), ('3.6', 2, 67), ('ZOE_ALL', 2, 68), ('3.3', 3, 69), ('5day.4.17', 0, 70), ('2day.4.14', 0, 71), ('3.3', 3, 72), ('2.28', 0, 73), ('2day.4.14', 2, 74), ('3.6', 2, 75), ('5day.4.17', 2, 76), ('1day.4.13', 1, 77), ('3.6', 1, 78), ('1day.4.13', 0, 79), ('5day.4.17', 2, 80), ('2day.4.14', 1, 81), ('2.28', 3, 82), ('2.28', 2, 83), ('2day.4.14', 0, 84), ('1day.4.13', 2, 85), ('3.3', 3, 86), ('2day.4.14', 2, 87), ('3day.4.15', 0, 88), ('ZOE_ALL', 3, 89), ('2.28', 2, 90), ('1day.4.13', 2, 91), ('1day.4.13', 0, 92), ('3.6', 1, 93), ('5day.4.17', 1, 94), ('2.28', 1, 95), ('2day.4.14', 1, 96), ('3day.4.15', 0, 97), ('5day.4.17', 2, 98), ('2day.4.14', 1, 99), ('3.6', 3, 100), ('2day.4.14', 1, 101), ('2day.4.14', 1, 102), ('2day.4.14', 1, 103), ('3.3', 1, 104), ('3.6', 0, 105), ('2.28', 2, 106), ('3.6', 3, 107), ('2.28', 0, 108), ('2.28', 2, 109), ('3.3', 1, 110), ('ZOE_ALL', 2, 111), ('3.3', 1, 112), ('3day.4.15', 0, 113), ('3.3', 1, 114), ('1day.4.13', 1, 115), ('3.3', 3, 116), ('2day.4.14', 1, 117), ('5day.4.17', 0, 118), ('2day.4.14', 0, 119), ('3day.4.15', 2, 120), ('5day.4.17', 1, 121), ('3.6', 3, 122), ('5day.4.17', 2, 123), ('3day.4.15', 2, 124), ('3.6', 1, 125), ('3day.4.15', 0, 126), ('1day.4.13', 2, 127), ('1day.4.13', 2, 0), ('1day.4.13', 0, 1), ('ZOE_ALL', 0, 2), ('3.6', 3, 3), ('ZOE_ALL', 1, 4), ('5day.4.17', 1, 5), ('3.3', 0, 6), ('3day.4.15', 2, 7), ('5day.4.17', 1, 8), ('3.6', 3, 9), ('2day.4.14', 2, 10), ('ZOE_ALL', 2, 11), ('5day.4.17', 2, 12), ('ZOE_ALL', 3, 13), ('3.3', 1, 14), ('5day.4.17', 0, 15), ('3.3', 2, 16), ('ZOE_ALL', 0, 17), ('5day.4.17', 0, 18), ('2day.4.14', 2, 19), ('2day.4.14', 0, 20), ('3day.4.15', 2, 21), ('2.28', 3, 22), ('3.6', 0, 23), ('3.3', 1, 24), ('2.28', 2, 25), ('5day.4.17', 0, 26), ('2day.4.14', 2, 27), ('1day.4.13', 1, 28), ('ZOE_ALL', 0, 29), ('ZOE_ALL', 1, 30), ('3.3', 3, 31), ('3.6', 2, 32), ('3.3', 1, 33), ('3.6', 1, 34), ('2.28', 1, 35), ('2.28', 3, 36), ('5day.4.17', 1, 37), ('3.3', 1, 38), ('1day.4.13', 0, 39), ('3day.4.15', 2, 40), ('ZOE_ALL', 1, 41), ('2.28', 1, 42), ('3.3', 3, 43), ('3.3', 3, 44), ('2.28', 1, 45), ('3.3', 2, 46), ('3.6', 0, 47), ('5day.4.17', 0, 48), ('5day.4.17', 0, 49), ('ZOE_ALL', 1, 50), ('2day.4.14', 1, 51), ('3day.4.15', 1, 52), ('3.3', 2, 53), ('2.28', 3, 54), ('3.3', 3, 55), ('ZOE_ALL', 1, 56), ('2.28', 1, 57), ('2day.4.14', 1, 58), ('3.6', 0, 59), ('3day.4.15', 2, 60), ('ZOE_ALL', 3, 61), ('3.6', 1, 62), ('2day.4.14', 0, 63), ('ZOE_ALL', 3, 64), ('1day.4.13', 0, 65), ('3.3', 0, 66), ('3.6', 0, 67), ('5day.4.17', 0, 68), ('2.28', 0, 69), ('ZOE_ALL', 1, 70), ('ZOE_ALL', 0, 71), ('2day.4.14', 2, 72), ('3.3', 2, 73), ('3day.4.15', 0, 74), ('5day.4.17', 1, 75), ('1day.4.13', 0, 76), ('ZOE_ALL', 3, 77), ('5day.4 ...

# %%
test_label_counts = all_preds_and_labels.groupby(['True Class', 'File Group']).count()
print(test_label_counts)
# Out:
#                        Prediction  Predicted Probs
# True Class File Group
# 0          1day.4.13           19               19
#            2.28                20               20
#            2day.4.14           19               19
#            3.3                 10               10
#            3.6                 19               19
#            3day.4.15           20               20
#            5day.4.17           20               20
#            ZOE_ALL             20               20
# 1          1day.4.13           19               19
#            2.28                18               18
#            2day.4.14           20               20
#            3.3                 20               20
#            3.6                 20               20
#            3day.4.15           20               20
#            5day.4.17           20               20
#            ZOE_ALL             20               20
# 2          1day.4.13           19               19
#            2.28                19               19
#            2day.4.14           20               20
#            3.3                 19               19
#            3.6                 17               17
#            3day.4.15           19               19
#            5day.4.17           20               20
#            ZOE_ALL             19               19
# 3          2.28                19               19
#            3.3                 19               19
#            3.6                 20               20
#            ZOE_ALL             19               19

# %%
train_label_counts = all_train_labels.groupby(['True Class', 'File Group']).count()
print(train_label_counts)
# Out:
#                        ID
# True Class File Group
# 0          1day.4.13   62
#            2.28        60
#            2day.4.14   62
#            3.3         30
#            3.6         60
#            3day.4.15   60
#            5day.4.17   60
#            ZOE_ALL     60
# 1          1day.4.13   62
#            2.28        59
#            2day.4.14   60
#            3.3         60
#            3.6         60
#            3day.4.15   60
#            5day.4.17   60
#            ZOE_ALL     60
# 2          1day.4.13   61
#            2.28        59
#            2day.4.14   60
#            3.3         59
#            3.6         53
#            3day.4.15   59
#            5day.4.17   60
#            ZOE_ALL     61
# 3          2.28        60
#            3.3         60
#            3.6         60
#            ZOE_ALL     63
