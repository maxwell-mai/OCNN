# %%
import torchvision
import torch
import numpy as np
import os
import PIL.Image
import time
import copy
import seaborn as sn
import pandas as pd
import sklearn.metrics
from matplotlib import pyplot as plt
from math import ceil

# %%
class OstVisDataset(torch.utils.data.Dataset):
    def __init__(self, roots, transforms, subset, label_map, exclude_subfolders = None, split = (.6,.2,.2)):
        # list of root folders
        self.roots = roots

        # list of subfolders to exclude from sampling (e.g. if you only want control_well 1 and adipogenic differentiation)
        self.exclude_subfolders = exclude_subfolders

        # torchvision composed transforms
        self.transforms = transforms

        # dict mapping subfolder names to labels
        self.label_map = label_map

        # getting files
        self.enumerated_files = self.depthwise_enumerate(subset,split)

    def depthwise_enumerate(self, subset, split): 
        all_files = []
        # for each root folder
        for i in self.roots:
            # get subfolders
            folders = [f for f in os.listdir(i) if '.' not in f]
            
            if self.exclude_subfolders:
                folders = [f for f in folders if f.lower() not in self.exclude_subfolders]

            for j in folders:
                # get files from folders
                files = [i + j + '/' + f for f in os.listdir(i + j) if '.tif' in f]

                # copy files list
                files_copy = files.copy()

                # calculate sample size then select the proper subset
                train_size = ceil(len(files) * split[0])
                
                if subset == 'train':
                    upper_bound = train_size
                    files = files_copy[:upper_bound]
                elif subset == 'valid': 
                    lower_bound = train_size
                    upper_bound = train_size + ceil(len(files) * split[1])
                    files = files_copy[lower_bound:upper_bound]
                else:
                    lower_bound = train_size + ceil(len(files) * split[1])
                    files = files_copy[lower_bound:]
                
                # extend all files list by the file list for subfolder j
                all_files.extend(files)
        
        # return flat list of files
        return all_files
    
    def __len__(self):
        return len(self.enumerated_files)
    
    def __getitem__(self, idx):
        # check type
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        # get image at position idx in enumerated list
        image_path = self.enumerated_files[idx]
        image = PIL.Image.open(image_path).convert('RGB')
        
        # apply tranforms
        image = self.transforms(image)
        
        # separate subfolder name from path
        image_path_parts = image_path.split('/')

        # determine label
        label = self.label_map[image_path_parts[1].lower()]
        
        # return ((path, image), output) pair We will use path to track accuracy for each class: 7 day, 10 day, etc
        return ((image_path_parts[0], image), label)

# %%
def load_model(device):
    model_ft = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.IMAGENET1K_V1)
    num_ftrs = model_ft.fc.in_features
    # Here the size of each output sample is set to 2.
    # Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
    model_ft.fc = torch.nn.Linear(num_ftrs, 2)

    model_ft = model_ft.to(device)

    criterion = torch.nn.CrossEntropyLoss()

    # Observe that all parameters are being optimized
    optimizer_ft = torch.optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

    # Decay LR by a factor of 0.1 every 7 epochs
    exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
    return model_ft, criterion, exp_lr_scheduler, optimizer_ft

def train_model(model, criterion, optimizer, scheduler, device, dataloaders, dataset_sizes, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0


            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs[1].to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    #print("outputs", outputs)
                    _, preds = torch.max(outputs, 1)
                    #print("preds", preds)
                    loss = criterion(outputs, labels)
                    #print(preds)
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
# initial construction of torch Dataset object
split_names = ['train', 'valid', 'test']
roots = ['2.28/', '1day.4.13/', '3.3/', '2day.4.14/', '3day.4.15/', '3.6/', '5day.4.17/','ZOE_ALL/']
label_map = {
    'control_well 1': 0,
    'adipogenic differentiation' : 1,
    'control' : 0,
    'adi-well-1' : 1,
    'adi-well-2' : 1,
    'ctrl-well-1' : 0,
    'ctrl-well-2' : 0,
    'adi' : 1,
    'crl' : 0,
}



data_transforms = {
    'train': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.RandomResizedCrop(224),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}


datasets = {split: OstVisDataset(roots= roots,
                      transforms= data_transforms[split],
                      subset= split,
                      label_map = label_map,
                      exclude_subfolders=['split', 'ost', 'adipogenic + osteogenic', 'osteogenic differentiation', 'osteogenic + adipogenic', 'osteogenic', 'ost-well-1', 'ost-well-2', 'ost+adi-well-1', 'ost+adi-well-2'],
                      split=(.6,.2,.2)) 
                      for split in split_names
            }

for i in datasets['train'].enumerated_files:
    if i in datasets['valid'].enumerated_files or i in datasets['test'].enumerated_files:
        print('Duplicate Found: ', i)

for i in datasets['valid'].enumerated_files:
    if i in datasets['train'].enumerated_files or i in datasets['test'].enumerated_files:
        print('Duplicate Found: ', i)

# constructing dataloaders
dataloaders = {split : torch.utils.data.DataLoader(datasets[split], shuffle=True, batch_size=128, num_workers=0) for split in split_names}

# getting lens
dataset_sizes = {split : len(datasets[split]) for split in split_names}
print(dataset_sizes)

# constructing device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# load model
model_ft, criterion, exp_lr_scheduler, optimizer_ft = load_model(device)

print('Train files:', datasets['train'].enumerated_files)
print('Validation files:', datasets['valid'].enumerated_files)
print('Testing files:', datasets['test'].enumerated_files)
# Out:
# {'train': 935, 'valid': 313, 'test': 304}
# Train files: ['2.28/adipogenic differentiation/0228-pl2-adi-w1-df-1.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-10.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-11.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-12.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-13.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-14.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-15.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-16.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-17.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-18.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-19.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-2.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-20.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-21.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-22.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-23.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-24.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-25.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-26.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-27.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-28.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-29.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-3.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-30.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-31.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-32.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-33.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-34.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-38.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-39.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-4.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-40.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-41.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-42.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-43.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-44.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-45.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-46.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-47.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-48.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-49.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-5.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-50.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-6.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-7.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-8.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w1-df-9.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-1.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-10.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-11.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-12.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-13.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-14.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-15.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-16.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-17.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-18.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-19.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-2.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-1.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-10.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-11.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-12.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-13.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-14.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-15.tif', '2.28/control_well 1/0228-pl2-ctl-w1-df-16.tif', '2.28/c ...
# Validation files: ['2.28/adipogenic differentiation/0228-pl2-adi-w2-df-20.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-21.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-22.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-23.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-24.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-25.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-26.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-27.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-28.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-29.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-3.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-30.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-31.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-32.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-33.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-34.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-35.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-36.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-37.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-38.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-19.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-2.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-20.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-21.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-22.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-23.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-24.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-25.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-26.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-27.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-28.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-29.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-3.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-30.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-31.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-32.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-33.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-34.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-35.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-36.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13459.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13460.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13461.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13462.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13463.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13464.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13465.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13466.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13467.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13468.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13469.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13470.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13471.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13472.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13473.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13474.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13475.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13476.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13477.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13478.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13479.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13256.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13257.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13258.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13259.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13260.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13261.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13262.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13263.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13264.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13265.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13266.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13267.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13268.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13269.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13270.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13271.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13272.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13273.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13274.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13275.tif', '1day.4.13/crl/IMG_BR ...
# Testing files: ['2.28/adipogenic differentiation/0228-pl2-adi-w2-df-39.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-4.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-40.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-41.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-42.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-43.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-44.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-45.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-46.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-47.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-48.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-49.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-5.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-50.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-6.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-7.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-8.tif', '2.28/adipogenic differentiation/0228-pl2-adi-w2-df-9.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-37.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-38.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-39.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-4.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-40.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-41.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-42.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-43.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-44.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-45.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-46.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-47.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-48.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-49.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-5.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-50.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-6.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-7.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-8.tif', '2.28/control_well 1/0228-pl2-ctl-w2-df-9.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13480.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13481.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13482.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13483.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13484.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13485.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13486.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13487.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13488.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13489.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13490.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13491.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13492.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13493.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13494.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13495.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13496.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13497.tif', '1day.4.13/adi/IMG_BRIGHTFIELD_13498.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13277.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13278.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13279.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13280.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13281.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13282.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13283.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13284.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13285.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13286.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13287.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13288.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13289.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13290.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13291.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13292.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13293.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13294.tif', '1day.4.13/crl/IMG_BRIGHTFIELD_13295.tif', '3.3/Adipogenic differentiation/0303-pl2-adi-w2-df-37.tif', '3.3/Adipogenic differentiation/0303-pl2-adi-w2-df-38.tif', '3.3/Adipogenic differentiation/0303-pl2-adi-w2-df-39.tif', '3.3/Adipogenic differentiation/0303-pl2-adi-w2-df-4.tif', '3.3/Adipogenic differentiation/0303-pl2-adi- ...

# %%
# train model
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,device, dataloaders, dataset_sizes,
                      num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.6853 Acc: 0.5647
# valid Loss: 0.6110 Acc: 0.6645
#
# Epoch 1/29
# ----------
# train Loss: 0.5395 Acc: 0.8053
# valid Loss: 0.4998 Acc: 0.7955
#
# Epoch 2/29
# ----------
# train Loss: 0.4144 Acc: 0.8513
# valid Loss: 0.3941 Acc: 0.8498
#
# Epoch 3/29
# ----------
# train Loss: 0.3202 Acc: 0.8995
# valid Loss: 0.3562 Acc: 0.8083
#
# Epoch 4/29
# ----------
# train Loss: 0.2678 Acc: 0.9037
# valid Loss: 0.4774 Acc: 0.7412
#
# Epoch 5/29
# ----------
# train Loss: 0.2166 Acc: 0.9283
# valid Loss: 0.2497 Acc: 0.8850
#
# Epoch 6/29
# ----------
# train Loss: 0.1687 Acc: 0.9508
# valid Loss: 0.5737 Acc: 0.7540
#
# Epoch 7/29
# ----------
# train Loss: 0.1606 Acc: 0.9358
# valid Loss: 0.3150 Acc: 0.8435
#
# Epoch 8/29
# ----------
# train Loss: 0.1509 Acc: 0.9422
# valid Loss: 0.2177 Acc: 0.9042
#
# Epoch 9/29
# ----------
# train Loss: 0.1481 Acc: 0.9487
# valid Loss: 0.1663 Acc: 0.9425
#
# Epoch 10/29
# ----------
# train Loss: 0.1554 Acc: 0.9401
# valid Loss: 0.1838 Acc: 0.9329
#
# Epoch 11/29
# ----------
# train Loss: 0.1473 Acc: 0.9497
# valid Loss: 0.1924 Acc: 0.9233
#
# Epoch 12/29
# ----------
# train Loss: 0.1535 Acc: 0.9422
# valid Loss: 0.2095 Acc: 0.9105
#
# Epoch 13/29
# ----------
# train Loss: 0.1444 Acc: 0.9497
# valid Loss: 0.2188 Acc: 0.9105
#
# Epoch 14/29
# ----------
# train Loss: 0.1467 Acc: 0.9487
# valid Loss: 0.1974 Acc: 0.9201
#
# Epoch 15/29
# ----------
# train Loss: 0.1427 Acc: 0.9529
# valid Loss: 0.1859 Acc: 0.9329
#
# Epoch 16/29
# ----------
# train Loss: 0.1319 Acc: 0.9551
# valid Loss: 0.1944 Acc: 0.9233
#
# Epoch 17/29
# ----------
# train Loss: 0.1420 Acc: 0.9519
# valid Loss: 0.1923 Acc: 0.9265
#
# Epoch 18/29
# ----------
# train Loss: 0.1428 Acc: 0.9487
# valid Loss: 0.1980 Acc: 0.9201
#
# Epoch 19/29
# ----------
# train Loss: 0.1339 Acc: 0.9594
# valid Loss: 0.1975 Acc: 0.9201
#
# Epoch 20/29
# ----------
# train Loss: 0.1339 Acc: 0.9583
# valid Loss: 0.1961 Acc: 0.9265
#
# Epoch 21/29
# ----------
# train Loss: 0.1362 Acc: 0.9487
# valid Loss: 0.1941 Acc: 0.9265
#
# Epoch 22/29
# ----------
# train Loss: 0.1292 Acc: 0.9583
# valid Loss: 0.1939 Acc: 0.9233
#
# Epoch 23/29
# ----------
# train Loss: 0.1379 Acc: 0.9561
# valid Loss: 0.2012 Acc: 0.9201
#
# Epoch 24/29
# ----------
# train Loss: 0.1483 Acc: 0.9519
# valid Loss: 0.1923 Acc: 0.9233
#
# Epoch 25/29
# ----------
# train Loss: 0.1372 Acc: 0.9561
# valid Loss: 0.1886 Acc: 0.9265
#
# Epoch 26/29
# ----------
# train Loss: 0.1244 Acc: 0.9572
# valid Loss: 0.1924 Acc: 0.9233
#
# Epoch 27/29
# ----------
# train Loss: 0.1472 Acc: 0.9487
# valid Loss: 0.1822 Acc: 0.9329
#
# Epoch 28/29
# ----------
# train Loss: 0.1208 Acc: 0.9626
# valid Loss: 0.1951 Acc: 0.9233
#
# Epoch 29/29
# ----------
# train Loss: 0.1341 Acc: 0.9540
# valid Loss: 0.1925 Acc: 0.9233
#
# Training complete in 196m 59s
# Best val Acc: 0.942492

# %%
torch.save(model_ft.state_dict(), 'OCNN_Binary_All_Days_State_Dict_Resnet50')

# %%
model_ft.load_state_dict(torch.load('OCNN_Binary_All_Days_State_Dict_Resnet50'))

model_ft.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %%
true = []
pred = []
pred_probs=[]

# making predictions
for i in dataloaders['test']:
    true.extend(list(zip([j for j in i[0][0]], [int(j) for j in i[1]])))
    evals = model_ft(i[0][1])
    pred.extend([int(torch.argmax(j)) for j in evals])
    pred_probs.extend([torch.softmax(j, 0).detach().numpy() for j in evals])

# separating class label from filename 
true_numeric = [i[1] for i in true]

# overall metrics
print('Overall Accuracy: ', sklearn.metrics.accuracy_score(true_numeric, pred))
print('Overall Precision: ', sklearn.metrics.precision_score(true_numeric, pred))
print('Overall Recall: ', sklearn.metrics.recall_score(true_numeric, pred))
print('Overall F1: ', sklearn.metrics.f1_score(true_numeric, pred))
print('Overall AUC: ', sklearn.metrics.roc_auc_score(true_numeric, np.array(pred_probs)[:,1]))
# Out:
# Overall Accuracy:  0.9572368421052632
# Overall Precision:  0.9931506849315068
# Overall Recall:  0.9235668789808917
# Overall F1:  0.9570957095709571
# Overall AUC:  0.995840374366307

# %%
# labels for visual
class_names = ['No Differentiation', 'Adipogenic and/or Osteogenic']

# numeric confusion matrix
confusion_matrix = sklearn.metrics.confusion_matrix(true_numeric, pred)

# convert to df and make fancy confusion matrix
confusion_matrix_df = pd.DataFrame(confusion_matrix, index = class_names, columns = class_names)
sn.heatmap(confusion_matrix_df, annot=True, fmt='g', cbar=False, cmap='Blues', annot_kws={'fontsize' : 12})
# Out:
# <Axes: >

# %%
# roc curve
sklearn.metrics.RocCurveDisplay.from_predictions(true_numeric, np.array(pred_probs)[:,1])
plt.plot([0, 1], [0, 1], "k--", label="Random Chance (AUC = 0.5)")
plt.title('Resnet50 ROC Curve', fontname='Arial', fontsize=12)
plt.xlabel("False Positive Rate", fontname='Arial', fontsize=12)
plt.ylabel("True Positive Rate", fontname='Arial', fontsize=12)
plt.legend()

# %%
# computing metrics by class

all = []

for i in zip(true, pred, pred_probs):
    # basically flattening the true and pred class. i[0][0] is filename, i[0][1] is true class, i[1] is prediction
    all.append((i[0][0], i[0][1], i[1], i[2][1]))

# convert to dataframe for easy slicing
all_preds_and_labels = pd.DataFrame(all, columns=['File Group', 'True Class', 'Prediction', 'Pred Prob Positive'])

metrics_dict = dict()

# compute metrics for each filename
for i in set(all_preds_and_labels['File Group']):
    slice = all_preds_and_labels[all_preds_and_labels['File Group'] == i]
    metrics_dict['{} Accuracy'.format(i)] = sklearn.metrics.accuracy_score(np.array(slice['True Class']), np.array(slice['Prediction']))
    metrics_dict['{} Precision'.format(i)] = sklearn.metrics.precision_score(np.array(slice['True Class']), np.array(slice['Prediction']))
    metrics_dict['{} Recall'.format(i)] = sklearn.metrics.recall_score(np.array(slice['True Class']), np.array(slice['Prediction']))
    metrics_dict['{} F1'.format(i)] = sklearn.metrics.f1_score(np.array(slice['True Class']), np.array(slice['Prediction']))
    metrics_dict['{} AUC'.format(i)] = sklearn.metrics.roc_auc_score(np.array(slice['True Class']), np.array(slice['Pred Prob Positive']))

for i in metrics_dict.items():
    print(i)
# Out:
# ('1day.4.13 Accuracy', 1.0)
# ('1day.4.13 Precision', 1.0)
# ('1day.4.13 Recall', 1.0)
# ('1day.4.13 F1', 1.0)
# ('1day.4.13 AUC', 1.0)
# ('3.3 Accuracy', 1.0)
# ('3.3 Precision', 1.0)
# ('3.3 Recall', 1.0)
# ('3.3 F1', 1.0)
# ('3.3 AUC', 1.0)
# ('2day.4.14 Accuracy', 0.9230769230769231)
# ('2day.4.14 Precision', 1.0)
# ('2day.4.14 Recall', 0.85)
# ('2day.4.14 F1', 0.9189189189189189)
# ('2day.4.14 AUC', 1.0)
# ('ZOE_ALL Accuracy', 0.975)
# ('ZOE_ALL Precision', 1.0)
# ('ZOE_ALL Recall', 0.95)
# ('ZOE_ALL F1', 0.9743589743589743)
# ('ZOE_ALL AUC', 0.9974999999999999)
# ('5day.4.17 Accuracy', 0.975)
# ('5day.4.17 Precision', 0.9523809523809523)
# ('5day.4.17 Recall', 1.0)
# ('5day.4.17 F1', 0.975609756097561)
# ('5day.4.17 AUC', 1.0)
# ('3.6 Accuracy', 1.0)
# ('3.6 Precision', 1.0)
# ('3.6 Recall', 1.0)
# ('3.6 F1', 1.0)
# ('3.6 AUC', 1.0)
# ('2.28 Accuracy', 1.0)
# ('2.28 Precision', 1.0)
# ('2.28 Recall', 1.0)
# ('2.28 F1', 1.0)
# ('2.28 AUC', 1.0)
# ('3day.4.15 Accuracy', 0.8)
# ('3day.4.15 Precision', 1.0)
# ('3day.4.15 Recall', 0.6)
# ('3day.4.15 F1', 0.7499999999999999)
# ('3day.4.15 AUC', 1.0)

# %%
true_train = []

# making predictions
for i in dataloaders['train']:
    true_train.extend(list(zip([j for j in i[0][0]], [int(j) for j in i[1]], [j for j in range(len(i[1]))])))
print(true_train)
all_train_labels = pd.DataFrame(true_train, columns=['File Group', 'True Class', 'ID'])
# Out:
# [('2day.4.14', 0, 0), ('ZOE_ALL', 1, 1), ('3.3', 0, 2), ('3day.4.15', 1, 3), ('2day.4.14', 0, 4), ('2.28', 0, 5), ('2day.4.14', 1, 6), ('ZOE_ALL', 1, 7), ('3.3', 1, 8), ('2.28', 1, 9), ('ZOE_ALL', 1, 10), ('3.3', 1, 11), ('1day.4.13', 0, 12), ('3day.4.15', 0, 13), ('5day.4.17', 0, 14), ('5day.4.17', 0, 15), ('3day.4.15', 0, 16), ('3day.4.15', 1, 17), ('3.6', 1, 18), ('3.3', 1, 19), ('3day.4.15', 0, 20), ('1day.4.13', 0, 21), ('5day.4.17', 0, 22), ('1day.4.13', 0, 23), ('2day.4.14', 0, 24), ('3.3', 0, 25), ('3.3', 0, 26), ('2day.4.14', 0, 27), ('ZOE_ALL', 1, 28), ('3day.4.15', 1, 29), ('3.6', 1, 30), ('3day.4.15', 0, 31), ('ZOE_ALL', 0, 32), ('2day.4.14', 1, 33), ('1day.4.13', 0, 34), ('1day.4.13', 0, 35), ('5day.4.17', 1, 36), ('5day.4.17', 0, 37), ('2.28', 0, 38), ('1day.4.13', 1, 39), ('2day.4.14', 1, 40), ('ZOE_ALL', 0, 41), ('2.28', 0, 42), ('3.6', 0, 43), ('1day.4.13', 1, 44), ('ZOE_ALL', 0, 45), ('3.3', 0, 46), ('5day.4.17', 1, 47), ('2.28', 1, 48), ('3.6', 0, 49), ('2.28', 0, 50), ('2.28', 0, 51), ('2.28', 0, 52), ('1day.4.13', 1, 53), ('ZOE_ALL', 0, 54), ('ZOE_ALL', 1, 55), ('5day.4.17', 1, 56), ('ZOE_ALL', 0, 57), ('3day.4.15', 1, 58), ('3.6', 1, 59), ('2day.4.14', 1, 60), ('2.28', 1, 61), ('2day.4.14', 0, 62), ('1day.4.13', 1, 63), ('1day.4.13', 0, 64), ('3.6', 0, 65), ('1day.4.13', 0, 66), ('3.3', 1, 67), ('2day.4.14', 1, 68), ('ZOE_ALL', 0, 69), ('3day.4.15', 0, 70), ('3day.4.15', 0, 71), ('3.6', 0, 72), ('3.3', 1, 73), ('ZOE_ALL', 1, 74), ('3day.4.15', 1, 75), ('5day.4.17', 0, 76), ('5day.4.17', 0, 77), ('2.28', 0, 78), ('3.3', 1, 79), ('3.3', 1, 80), ('2.28', 0, 81), ('1day.4.13', 0, 82), ('2day.4.14', 0, 83), ('5day.4.17', 0, 84), ('3.6', 0, 85), ('ZOE_ALL', 0, 86), ('5day.4.17', 0, 87), ('2.28', 1, 88), ('2.28', 1, 89), ('3.6', 0, 90), ('2.28', 1, 91), ('3.3', 1, 92), ('2day.4.14', 1, 93), ('ZOE_ALL', 1, 94), ('5day.4.17', 0, 95), ('3.6', 0, 96), ('3day.4.15', 0, 97), ('3day.4.15', 1, 98), ('3.3', 1, 99), ('3.6', 1, 100), ('ZOE_ALL', 1, 101), ('3.6', 1, 102), ('ZOE_ALL', 1, 103), ('1day.4.13', 0, 104), ('2.28', 1, 105), ('1day.4.13', 1, 106), ('ZOE_ALL', 1, 107), ('5day.4.17', 1, 108), ('3.6', 0, 109), ('ZOE_ALL', 0, 110), ('1day.4.13', 0, 111), ('3.3', 1, 112), ('3.3', 1, 113), ('2.28', 1, 114), ('ZOE_ALL', 0, 115), ('1day.4.13', 1, 116), ('2day.4.14', 1, 117), ('ZOE_ALL', 0, 118), ('2.28', 1, 119), ('1day.4.13', 1, 120), ('3.6', 1, 121), ('ZOE_ALL', 1, 122), ('5day.4.17', 1, 123), ('ZOE_ALL', 0, 124), ('2day.4.14', 0, 125), ('3.3', 1, 126), ('ZOE_ALL', 0, 127), ('5day.4.17', 1, 0), ('ZOE_ALL', 1, 1), ('3.6', 1, 2), ('ZOE_ALL', 0, 3), ('1day.4.13', 1, 4), ('3.6', 1, 5), ('2day.4.14', 0, 6), ('3.6', 0, 7), ('3.3', 1, 8), ('3.6', 0, 9), ('2.28', 1, 10), ('3.3', 1, 11), ('3.6', 0, 12), ('2.28', 0, 13), ('2day.4.14', 1, 14), ('3.3', 0, 15), ('1day.4.13', 1, 16), ('2day.4.14', 0, 17), ('3.3', 1, 18), ('1day.4.13', 1, 19), ('2.28', 0, 20), ('1day.4.13', 1, 21), ('3.3', 1, 22), ('3day.4.15', 0, 23), ('5day.4.17', 0, 24), ('ZOE_ALL', 1, 25), ('1day.4.13', 1, 26), ('3day.4.15', 0, 27), ('3.6', 0, 28), ('2day.4.14', 1, 29), ('ZOE_ALL', 0, 30), ('3.6', 1, 31), ('3.6', 0, 32), ('2day.4.14', 1, 33), ('2day.4.14', 0, 34), ('3day.4.15', 0, 35), ('2.28', 0, 36), ('5day.4.17', 1, 37), ('ZOE_ALL', 0, 38), ('5day.4.17', 0, 39), ('3.3', 1, 40), ('1day.4.13', 0, 41), ('3day.4.15', 1, 42), ('5day.4.17', 1, 43), ('1day.4.13', 1, 44), ('3.6', 0, 45), ('ZOE_ALL', 0, 46), ('3.6', 1, 47), ('2day.4.14', 0, 48), ('ZOE_ALL', 0, 49), ('3day.4.15', 0, 50), ('3.6', 0, 51), ('3.6', 1, 52), ('2.28', 0, 53), ('3day.4.15', 1, 54), ('3.6', 0, 55), ('3day.4.15', 1, 56), ('3day.4.15', 1, 57), ('1day.4.13', 0, 58), ('3.6', 0, 59), ('3.6', 0, 60), ('2.28', 0, 61), ('5day.4.17', 0, 62), ('3.3', 1, 63), ('3day.4.15', 0, 64), ('2.28', 0, 65), ('1day.4.13', 1, 66), ('3day.4.15', 1, 67), ('5day.4.17', 1, 68), ('3.6', 1, 69), ('ZOE_ALL', 1, 70), ('2.28', 1, 71), ('2.28', 1, 72), ('5day.4.17', 1, 73), ('1day.4.13', 1, 74), ('3.3', 1, 75), ('3.3', 0, 76), ('3 ...

# %%
test_label_counts = all_preds_and_labels.groupby(['True Class', 'File Group']).count()
print(test_label_counts)
# Out:
#                        Prediction  Pred Prob Positive
# True Class File Group
# 0          1day.4.13           19                  19
#            2.28                20                  20
#            2day.4.14           19                  19
#            3.3                 10                  10
#            3.6                 19                  19
#            3day.4.15           20                  20
#            5day.4.17           20                  20
#            ZOE_ALL             20                  20
# 1          1day.4.13           19                  19
#            2.28                18                  18
#            2day.4.14           20                  20
#            3.3                 20                  20
#            3.6                 20                  20
#            3day.4.15           20                  20
#            5day.4.17           20                  20
#            ZOE_ALL             20                  20

# %%
train_label_counts = all_train_labels.groupby(['True Class', 'File Group']).count()
print(train_label_counts)
# Out:
#                        ID
# True Class File Group
# 0          1day.4.13   62
#            2.28        60
#            2day.4.14   62
#            3.3         30
#            3.6         60
#            3day.4.15   60
#            5day.4.17   60
#            ZOE_ALL     60
# 1          1day.4.13   62
#            2.28        59
#            2day.4.14   60
#            3.3         60
#            3.6         60
#            3day.4.15   60
#            5day.4.17   60
#            ZOE_ALL     60
